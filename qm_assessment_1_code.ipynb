# %%
# %matplotlib inline

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

DATA_FILEPATH = "coursework_1_data_2019.csv"
df = pd.read_csv(DATA_FILEPATH)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 152 entries, 0 to 151
# Data columns (total 28 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   local_authority_area  152 non-null    object
#  1   2008_cases_total      152 non-null    int64
#  2   2013_cases_total      152 non-null    int64
#  3   2018_cases_total      152 non-null    int64
#  4   2008_pop_total        152 non-null    int64
#  5   2013_pop_total        152 non-null    int64
#  6   2018_pop_total        152 non-null    int64
#  7   2008_cases_male       152 non-null    int64
#  8   2013_cases_male       152 non-null    int64
#  9   2018_cases_male       152 non-null    int64
#  10  2008_pop_male         152 non-null    int64
#  11  2013_pop_male         152 non-null    int64
#  12  2018_pop_male         152 non-null    int64
#  13  2008_cases_female     152 non-null    int64
#  14  2013_cases_female     152 non-null    int64
# ...

# %%
df
# Out:
#              local_authority_area  2008_cases_total  2013_cases_total  \
# 0            Barking and Dagenham               593               619
# 1                          Barnet               539               594
# 2                        Barnsley               360               451
# 3    Bath and North East Somerset               456               421
# 4                         Bedford               311               327
# ..                            ...               ...               ...
# 147                        Wirral              2560              2652
# 148                     Wokingham               119               146
# 149                 Wolverhampton              1442              1571
# 150                Worcestershire              2718              3061
# 151                          York              1170              1266
#
#      2018_cases_total  2008_pop_total  2013_pop_total  2018_pop_total  \
# ...

# %%
df.iloc[0]
# Out:
# local_authority_area    Barking and Dagenham
# 2008_cases_total                         593
# 2013_cases_total                         619
# 2018_cases_total                         763
# 2008_pop_total                        172684
# 2013_pop_total                        179030
# 2018_pop_total                        181779
# 2008_cases_male                          187
# 2013_cases_male                          190
# 2018_cases_male                          230
# 2008_pop_male                          83890
# 2013_pop_male                          81915
# 2018_pop_male                          77983
# 2008_cases_female                        406
# 2013_cases_female                        429
# 2018_cases_female                        533
# 2008_pop_female                        88794
# 2013_pop_female                        97115
# 2018_pop_female                       103796
# total_budget                          139000
# clean_air                              21000
# ...

# %%
df.describe()
# Out:
#        2008_cases_total  2013_cases_total  2018_cases_total  2008_pop_total  \
# count        152.000000        152.000000        152.000000    1.520000e+02
# mean        1075.296053       1159.513158       1278.605263    3.409223e+05
# std          922.378705        997.231047       1069.691997    2.621354e+05
# min            5.000000          1.000000          4.000000    2.200000e+03
# 25%          493.500000        531.750000        592.500000    1.894748e+05
# 50%          729.000000        794.500000        873.500000    2.540925e+05
# 75%         1386.000000       1470.250000       1641.500000    3.751225e+05
# max         5065.000000       5582.000000       5745.000000    1.411380e+06
#
#        2013_pop_total  2018_pop_total  2008_cases_male  2013_cases_male  \
# count    1.520000e+02    1.520000e+02       152.000000       152.000000
# mean     3.542821e+05    3.682895e+05       375.796053       401.526316
# ...

# %%
pd.set_option('max_columns', None)

# %%
df.describe()
# Out:
#        2008_cases_total  2013_cases_total  2018_cases_total  2008_pop_total  \
# count        152.000000        152.000000        152.000000    1.520000e+02
# mean        1075.296053       1159.513158       1278.605263    3.409223e+05
# std          922.378705        997.231047       1069.691997    2.621354e+05
# min            5.000000          1.000000          4.000000    2.200000e+03
# 25%          493.500000        531.750000        592.500000    1.894748e+05
# 50%          729.000000        794.500000        873.500000    2.540925e+05
# 75%         1386.000000       1470.250000       1641.500000    3.751225e+05
# max         5065.000000       5582.000000       5745.000000    1.411380e+06
#
#        2013_pop_total  2018_pop_total  2008_cases_male  2013_cases_male  \
# count    1.520000e+02    1.520000e+02       152.000000       152.000000
# mean     3.542821e+05    3.682895e+05       375.796053       401.526316
# ...

# %%
df.iloc[0:2]
# Out:
#    local_authority_area  2008_cases_total  2013_cases_total  2018_cases_total  \
# 0  Barking and Dagenham               593               619               763
# 1                Barnet               539               594               773
#
#    2008_pop_total  2013_pop_total  2018_pop_total  2008_cases_male  \
# 0          172684          179030          181779              187
# 1          340435          344062          355955              212
#
#    2013_cases_male  2018_cases_male  2008_pop_male  2013_pop_male  \
# 0              190              230          83890          81915
# 1              204              292         169060         161533
#
#    2018_pop_male  2008_cases_female  2013_cases_female  2018_cases_female  \
# 0          77983                406                429                533
# 1         161769                327                390                481
#
#    2008_pop_female  2013_pop_female  2018_pop_female  total_budget  clean_air  \
# ...

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df[["2008_cases_total","2013_cases_total","2018_cases_total"]].plot()
# Out:
# <AxesSubplot:>

# %%
df.loc[df["local_authority_area"] == "Barking and Dagenham"][["2008_cases_total","2013_cases_total","2018_cases_total"]].plot()
# Out:
# <AxesSubplot:>

# %%
df["2008_obesity_percentage_pop"] = (df["2008_cases_total"] / df["2008_pop_total"])*100

# %%
df.iloc[0]
# Out:
# local_authority_area           Barking and Dagenham
# 2008_cases_total                                593
# 2013_cases_total                                619
# 2018_cases_total                                763
# 2008_pop_total                               172684
# 2013_pop_total                               179030
# 2018_pop_total                               181779
# 2008_cases_male                                 187
# 2013_cases_male                                 190
# 2018_cases_male                                 230
# 2008_pop_male                                 83890
# 2013_pop_male                                 81915
# 2018_pop_male                                 77983
# 2008_cases_female                               406
# 2013_cases_female                               429
# 2018_cases_female                               533
# 2008_pop_female                               88794
# 2013_pop_female                               97115
# ...

# %%
df
# Out:
#              local_authority_area  2008_cases_total  2013_cases_total  \
# 0            Barking and Dagenham               593               619
# 1                          Barnet               539               594
# 2                        Barnsley               360               451
# 3    Bath and North East Somerset               456               421
# 4                         Bedford               311               327
# ..                            ...               ...               ...
# 147                        Wirral              2560              2652
# 148                     Wokingham               119               146
# 149                 Wolverhampton              1442              1571
# 150                Worcestershire              2718              3061
# 151                          York              1170              1266
#
#      2018_cases_total  2008_pop_total  2013_pop_total  2018_pop_total  \
# ...

# %%
df["2013_obesity_percentage_pop"] = (df["2013_cases_total"] / df["2013_pop_total"])*100

# %%
df["2018_obesity_percentage_pop"] = (df["2018_cases_total"] / df["2018_pop_total"])*100

# %%
df
# Out:
#              local_authority_area  2008_cases_total  2013_cases_total  \
# 0            Barking and Dagenham               593               619
# 1                          Barnet               539               594
# 2                        Barnsley               360               451
# 3    Bath and North East Somerset               456               421
# 4                         Bedford               311               327
# ..                            ...               ...               ...
# 147                        Wirral              2560              2652
# 148                     Wokingham               119               146
# 149                 Wolverhampton              1442              1571
# 150                Worcestershire              2718              3061
# 151                          York              1170              1266
#
#      2018_cases_total  2008_pop_total  2013_pop_total  2018_pop_total  \
# ...

# %%
df["relative_change"] = df["2018_obesity_percentage_pop"] - df["2008_obesity_percentage_pop"]

# %%
df
# Out:
#              local_authority_area  2008_cases_total  2013_cases_total  \
# 0            Barking and Dagenham               593               619
# 1                          Barnet               539               594
# 2                        Barnsley               360               451
# 3    Bath and North East Somerset               456               421
# 4                         Bedford               311               327
# ..                            ...               ...               ...
# 147                        Wirral              2560              2652
# 148                     Wokingham               119               146
# 149                 Wolverhampton              1442              1571
# 150                Worcestershire              2718              3061
# 151                          York              1170              1266
#
#      2018_cases_total  2008_pop_total  2013_pop_total  2018_pop_total  \
# ...

# %%
df2 = df.copy()

# %%
df2.sort_values(by="relative_change", ascending=False)
# Out:
#        local_authority_area  2008_cases_total  2013_cases_total  \
# 46                  Hackney               916               938
# 7     Blackburn with Darwen               831               818
# 61   Kensington and Chelsea               298               287
# 118               Southwark               922               931
# 16                  Bromley               611               737
# ..                      ...               ...               ...
# 132                  Torbay               615               622
# 145               Wiltshire              1372              1474
# 80            Milton Keynes               839               869
# 105                 Rutland                88               102
# 59          Isles of Scilly                 5                 1
#
#      2018_cases_total  2008_pop_total  2013_pop_total  2018_pop_total  \
# 46               1072          214270          205973          202667
# ...

# %%
df2["budget_per_person"] = df2["total_budget"] / df2["2018_pop_total"]

# %%
df2.plot.scatter(x="relative_change", y="budget_per_person")
# Out:
# <AxesSubplot:xlabel='relative_change', ylabel='budget_per_person'>

# %%
df2.sort_values(by="relative_change", ascending=False)
# Out:
#        local_authority_area  2008_cases_total  2013_cases_total  \
# 46                  Hackney               916               938
# 7     Blackburn with Darwen               831               818
# 61   Kensington and Chelsea               298               287
# 118               Southwark               922               931
# 16                  Bromley               611               737
# ..                      ...               ...               ...
# 132                  Torbay               615               622
# 145               Wiltshire              1372              1474
# 80            Milton Keynes               839               869
# 105                 Rutland                88               102
# 59          Isles of Scilly                 5                 1
#
#      2018_cases_total  2008_pop_total  2013_pop_total  2018_pop_total  \
# 46               1072          214270          205973          202667
# ...

# %%
df2.corr().plot()
# Out:
# <AxesSubplot:>

# %%
df2.columns
# Out:
# Index(['local_authority_area', '2008_cases_total', '2013_cases_total',
#        '2018_cases_total', '2008_pop_total', '2013_pop_total',
#        '2018_pop_total', '2008_cases_male', '2013_cases_male',
#        '2018_cases_male', '2008_pop_male', '2013_pop_male', '2018_pop_male',
#        '2008_cases_female', '2013_cases_female', '2018_cases_female',
#        '2008_pop_female', '2013_pop_female', '2018_pop_female', 'total_budget',
#        'clean_air', 'clean_environ', 'health_training', 'school_awareness',
#        'media_awareness', 'sub_counselling', 'region', 'local_authority_type',
#        '2008_obesity_percentage_pop', '2013_obesity_percentage_pop',
#        '2018_obesity_percentage_pop', 'relative_change', 'budget_per_person'],
#       dtype='object')

# %%
from scipy import stats

# %%
t = stats.pearsonr(df2["2008_cases_total"], df2["2018_cases_total"])

# %%
df2["relative_change"].plot()
# Out:
# <AxesSubplot:>

# %%
df2
# Out:
#              local_authority_area  2008_cases_total  2013_cases_total  \
# 0            Barking and Dagenham               593               619
# 1                          Barnet               539               594
# 2                        Barnsley               360               451
# 3    Bath and North East Somerset               456               421
# 4                         Bedford               311               327
# ..                            ...               ...               ...
# 147                        Wirral              2560              2652
# 148                     Wokingham               119               146
# 149                 Wolverhampton              1442              1571
# 150                Worcestershire              2718              3061
# 151                          York              1170              1266
#
#      2018_cases_total  2008_pop_total  2013_pop_total  2018_pop_total  \
# ...

# %%
import seaborn as sns

# %%
df2[["2008_cases_male","2008_cases_female"]].plot()
# Out:
# <AxesSubplot:>

# %%
df2.sort_values(by="budget_per_person", ascending=False)
# Out:
#     local_authority_area  2008_cases_total  2013_cases_total  \
# 25        City of London                16                14
# 105              Rutland                88               102
# 133        Tower Hamlets               569               505
# 67               Lambeth               845               839
# 76            Manchester              1778              1845
# ..                   ...               ...               ...
# 92       Nottinghamshire              5065              5582
# 43             Gateshead               418               470
# 73          Lincolnshire              2015              2162
# 120        Staffordshire              4044              4357
# 54         Herefordshire               406               413
#
#      2018_cases_total  2008_pop_total  2013_pop_total  2018_pop_total  \
# 25                 12           11378            9838            8107
# 105                86           38363           39872           42952
# ...

# %%
df3 = df2.copy()

# %%
df3.drop(axis=0, index=25, inplace=True)

# %%
df3.sort_values(by="budget_per_person", ascending=False)
# Out:
#     local_authority_area  2008_cases_total  2013_cases_total  \
# 105              Rutland                88               102
# 133        Tower Hamlets               569               505
# 67               Lambeth               845               839
# 76            Manchester              1778              1845
# 52            Hartlepool               290               317
# ..                   ...               ...               ...
# 92       Nottinghamshire              5065              5582
# 43             Gateshead               418               470
# 73          Lincolnshire              2015              2162
# 120        Staffordshire              4044              4357
# 54         Herefordshire               406               413
#
#      2018_cases_total  2008_pop_total  2013_pop_total  2018_pop_total  \
# 105                86           38363           39872           42952
# 133               605          228366          193835          187282
# ...

# %%
t = stats.pearsonr(df3["budget_per_person"], df3["relative_change"])
t
# Out:
# (0.050980375033396155, 0.5341680884336596)

# %%
df2
# Out:
#              local_authority_area  2008_cases_total  2013_cases_total  \
# 0            Barking and Dagenham               593               619
# 1                          Barnet               539               594
# 2                        Barnsley               360               451
# 3    Bath and North East Somerset               456               421
# 4                         Bedford               311               327
# ..                            ...               ...               ...
# 147                        Wirral              2560              2652
# 148                     Wokingham               119               146
# 149                 Wolverhampton              1442              1571
# 150                Worcestershire              2718              3061
# 151                          York              1170              1266
#
#      2018_cases_total  2008_pop_total  2013_pop_total  2018_pop_total  \
# ...

# %%
df
# Out:
#              local_authority_area  2008_cases_total  2013_cases_total  \
# 0            Barking and Dagenham               593               619
# 1                          Barnet               539               594
# 2                        Barnsley               360               451
# 3    Bath and North East Somerset               456               421
# 4                         Bedford               311               327
# ..                            ...               ...               ...
# 147                        Wirral              2560              2652
# 148                     Wokingham               119               146
# 149                 Wolverhampton              1442              1571
# 150                Worcestershire              2718              3061
# 151                          York              1170              1266
#
#      2018_cases_total  2008_pop_total  2013_pop_total  2018_pop_total  \
# ...

# %%
df2.sort_values(by="region", ascending=False)
# Out:
#          local_authority_area  2008_cases_total  2013_cases_total  \
# 151                      York              1170              1266
# 39   East Riding of Yorkshire               976              1036
# 19                 Calderdale               663               680
# 34                  Doncaster              1073              1202
# 109                 Sheffield              1229              1457
# ..                        ...               ...               ...
# 89           Northamptonshire              3050              3213
# 32                 Derbyshire              3691              3905
# 92            Nottinghamshire              5065              5582
# 105                   Rutland                88               102
# 91                 Nottingham              2098              2226
#
#      2018_cases_total  2008_pop_total  2013_pop_total  2018_pop_total  \
# 151              1414          196246          202851          212083
# ...

# %%
df2["2008_obesity_percentage_pop"].plot().bar(x=df2["local_authority_area"], height = 1)
# Out:
# <BarContainer object of 152 artists>

# %%
df2.groupby("region").mean("2008_obesity_percentage_pop")
# Out:
#                           2008_cases_total  2013_cases_total  \
# region
# East Midlands                  2241.000000       2406.444444
# East of England                1359.000000       1445.545455
# London                          557.151515        605.121212
# North East                      470.166667        519.916667
# North West                     1141.000000       1215.652174
# South East                     1078.000000       1141.947368
# South West                     1080.375000       1170.812500
# West Midlands                  1654.071429       1806.142857
# Yorkshire and the Humber       1142.066667       1253.533333
#
#                           2018_cases_total  2008_pop_total  2013_pop_total  \
# region
# East Midlands                  2547.666667   495554.111111   525608.000000
# East of England                1580.363636   523353.090909   549339.000000
# London                          712.151515   233980.515152   232989.424242
# ...

# %%
df2.groupby("region").mean("2008_obesity_percentage_pop")
# Out:
#                           2008_cases_total  2013_cases_total  \
# region
# East Midlands                  2241.000000       2406.444444
# East of England                1359.000000       1445.545455
# London                          557.151515        605.121212
# North East                      470.166667        519.916667
# North West                     1141.000000       1215.652174
# South East                     1078.000000       1141.947368
# South West                     1080.375000       1170.812500
# West Midlands                  1654.071429       1806.142857
# Yorkshire and the Humber       1142.066667       1253.533333
#
#                           2018_cases_total  2008_pop_total  2013_pop_total  \
# region
# East Midlands                  2547.666667   495554.111111   525608.000000
# East of England                1580.363636   523353.090909   549339.000000
# London                          712.151515   233980.515152   232989.424242
# ...

# %%
df4 = df2.groupby("region").mean()

# %%
df4
# Out:
#                           2008_cases_total  2013_cases_total  \
# region
# East Midlands                  2241.000000       2406.444444
# East of England                1359.000000       1445.545455
# London                          557.151515        605.121212
# North East                      470.166667        519.916667
# North West                     1141.000000       1215.652174
# South East                     1078.000000       1141.947368
# South West                     1080.375000       1170.812500
# West Midlands                  1654.071429       1806.142857
# Yorkshire and the Humber       1142.066667       1253.533333
#
#                           2018_cases_total  2008_pop_total  2013_pop_total  \
# region
# East Midlands                  2547.666667   495554.111111   525608.000000
# East of England                1580.363636   523353.090909   549339.000000
# London                          712.151515   233980.515152   232989.424242
# ...

# %%
df4["2008_obesity_percentage_pop"].plot().barplot(x="regions", height="2008_obesity_percentage_pop")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/wh/dj91_4z15tn4k96j3939mh7w0000gn/T/ipykernel_19146/3326496361.py in <module>
# ----> 1 df4["2008_obesity_percentage_pop"].plot().barplot(x="regions", height="2008_obesity_percentage_pop")
#
# AttributeError: 'AxesSubplot' object has no attribute 'barplot'

# %%
df4.plot()
# Out:
# <AxesSubplot:xlabel='region'>

# %%
df4.sort_values(by="2008_obesity_percentage_pop", ascending=False)
# Out:
#                           2008_cases_total  2013_cases_total  \
# region
# East Midlands                  2241.000000       2406.444444
# West Midlands                  1654.071429       1806.142857
# North West                     1141.000000       1215.652174
# South West                     1080.375000       1170.812500
# Yorkshire and the Humber       1142.066667       1253.533333
# South East                     1078.000000       1141.947368
# East of England                1359.000000       1445.545455
# London                          557.151515        605.121212
# North East                      470.166667        519.916667
#
#                           2018_cases_total  2008_pop_total  2013_pop_total  \
# region
# East Midlands                  2547.666667   495554.111111   525608.000000
# West Midlands                  1952.928571   388989.285714   409988.714286
# North West                     1364.652174   300942.304348   309981.826087
# ...

# %%
sns.regplot(x=df4["relative_change"], y=df4["budget_per_person"])
# Out:
# <AxesSubplot:xlabel='relative_change', ylabel='budget_per_person'>

# %%
ordered = df4.sort_values(by="2008_obesity_percentage_pop", ascending=True)
my_range=range(1,len(df4.index)+1)

# %%
plt.hlines(y=my_range, xmin=ordered['2008_obesity_percentage_pop'], xmax=ordered['2018_obesity_percentage_pop'], color='grey', alpha=0.4)
plt.scatter(ordered['2008_obesity_percentage_pop'], my_range, color='skyblue', alpha=1, label='2008_obesity_percentage_pop')
plt.scatter(ordered['2018_obesity_percentage_pop'], my_range, color='green', alpha=0.4 , label='2018_obesity_percentage_pop')
plt.yticks(my_range, ordered.index)
plt.title("Comparison of obesity 2008 and 2018", loc='left')
plt.xlabel('% of total population')
plt.ylabel('Regions')
# Out:
# Text(0, 0.5, 'Regions')

# %%
df4.sort_values(by="total_budget", ascending=True)
# Out:
#                           2008_cases_total  2013_cases_total  \
# region
# North East                      470.166667        519.916667
# London                          557.151515        605.121212
# North West                     1141.000000       1215.652174
# South West                     1080.375000       1170.812500
# Yorkshire and the Humber       1142.066667       1253.533333
# West Midlands                  1654.071429       1806.142857
# East Midlands                  2241.000000       2406.444444
# South East                     1078.000000       1141.947368
# East of England                1359.000000       1445.545455
#
#                           2018_cases_total  2008_pop_total  2013_pop_total  \
# region
# North East                      593.666667   215687.583333   223006.583333
# London                          712.151515   233980.515152   232989.424242
# North West                     1364.652174   300942.304348   309981.826087
# ...

# %%
df4.index
# Out:
# Index(['East Midlands', 'East of England', 'London', 'North East',
#        'North West', 'South East', 'South West', 'West Midlands',
#        'Yorkshire and the Humber'],
#       dtype='object', name='region')

# %%
df4[["2008_cases_male","2008_cases_female"]].plot()
# Out:
# <AxesSubplot:xlabel='region'>

# %%
df2["2008_cases_female"].hist()
# Out:
# <AxesSubplot:>

# %%
df2[["2008_cases_male","2008_cases_female"]].hist()
# Out:
# array([[<AxesSubplot:title={'center':'2008_cases_male'}>,
#         <AxesSubplot:title={'center':'2008_cases_female'}>]], dtype=object)

# %%
plt.hist(x=df2["2008_cases_male"], bins=30, alpha=0.5)
plt.hist(x=df2["2008_cases_female"], bins=30, alpha=0.5)

plt.show()

# %%
df2["2008_cases_total"].hist(bins=30, alpha=0.3)
#df2["2013_cases_total"].hist(bins=30, alpha=0.3)
df2["2018_cases_total"].hist(bins=30, alpha=0.3)
# Out:
# <AxesSubplot:>
